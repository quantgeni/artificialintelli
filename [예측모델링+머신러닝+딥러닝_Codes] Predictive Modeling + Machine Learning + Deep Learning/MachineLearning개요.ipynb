# %%
print('machine learning')
# Out:
# machine learning

# %%
# 파이썬으로 배우는 머신러닝
# 인공지능의 개념

# 아서 사무엘의 정의 
# 컴퓨터가 경험을 통해 학습할 수 있도록 프로그래밍을 하되,
# 세세하게 프로그래밍해야 하는 번거로움을 벗어나게 하는 것

# 미셸의 정의
# 어떤 프로그램이 작업을 수행하고 작업의 성능을 평가했을때 경험을 통해 성능이 개선되었다면
# 이 프로그램은 학습한다고 말할 수 있다

# 인공지능의 범위
# 인공지능 > 머신러닝 > 딥러닝

# 인공지능 구현방식
# 초기에는 지식전달방식으로 구현

# => 개발자가 기계에게 일반적인 규칙을 알려줌
# => 심한 변화의 양상에는 잘 대처하지 못함

# 후기에는 데이터중심으로 구현
# => 데이터를 통해 기계가 학습(규칙/패턴인식)한 뒤
# => 새로운 데이터를 통해 예측/분류 함
# => 훈련을 위한 많은 양질의 데이터가 필요

# 인공지능의 역사
# 앨런 튜닝 - AI 용어 등장 - 1차 암흑기 - 2차 암흑기 - 체스챔피언 이김 - 퀴즈 챔피언 이김 - 4차 산업 혁명 - 바둑 챔피언 이김

# 인공지능의 미래
# 강 인공지능 vs. 약 인공지능

# 머신러닝 알고리즘 분류
# 지도학습 : 데이터와 레이블을 통해 훈련을 수행
#          : 분류 (범주형) / 회귀 (연속형)
#          : 로지스틱 회귀 / 선형 회귀
# 비지도학습 : 데이터만을 통해 훈련을 수행
#          : 군집 / 차원축소
#          : kmeans / pca
