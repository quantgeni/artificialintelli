# %%
#from urllib.request import urlopen
import sys
import re

#스크래핑한 결과를 저장한 파일로부터 내용을 읽어들여 화면에 출력

with open('data/01storemain.html','r',encoding='utf-8') as f:
    html=f.read() #이건 루프 돌면서 한줄씩 읽는게 아니라, 몽딴 한꺼번에 읽음
    
print(html)
# Out:
# <!DOCTYPE html>
# <html lang="ko">
# <head>
# <!--[if lte IE 8]>
# <script>
#   location.replace('/support/explorer_upgrade.html');
# </script>
# <![endif]-->
# <!-- Google Tag Manager -->
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-W9D5PM3');</script>
# <!-- End Google Tag Manager -->
# <meta charset="utf-8"/>
# <title>한빛출판네트워크</title>
# <link rel="shortcut icon" href="http://www.hanbit.co.kr/images/common/hanbit.ico">
# <meta http-equiv="X-UA-Compatible" content="IE=Edge" />
# <meta property="og:type" content="website"/>
# <meta property="og:title" content="한빛출판네트워크"/>
# <meta property="og:description" content="출판사, IT전문서, 대학교재, 경제경영, 어린이/유아, MAKE, 실용/여행, 전자책, 인터넷 강의"/>
# ...

# %%
import re
#도서 제목 추출 위해 정규표현식 이용. 파이썬 정규표현식 패키지는?? => re
htm=r'<p class="book_tit"><a.*?</p>'

i=0
for part_html in re.findall(htm,html,re.DOTALL):
    i+=1
    print(i)
    print(part_html)
# Out:
# 1
# <p class="book_tit"><a href="/store/books/look.php?p_code=B7009240426">리얼월드 HTTP : 역사와 코드로 배우는 인터넷과 웹 기술</a></p>
# 2
# <p class="book_tit"><a href="/store/books/look.php?p_code=E9650022874">데이터를 부탁해 : 세상을 움직이는 데이터의 힘</a></p>
# 3
# <p class="book_tit"><a href="/store/books/look.php?p_code=B6450703046">지금 당장 마케팅 공부하라&#40;최신개정판&#41;</a></p>
# 4
# <p class="book_tit"><a href="/store/books/look.php?p_code=B2974835990">제프리 리처의 Windows via C/C++&#40;복간판&#41;</a></p>
# 5
# <p class="book_tit"><a href="/store/books/look.php?p_code=B5346205345">초보자를 위한 유니티 입문&#40;개정판&#41; : 따라 하면서 배우는 2D & 3D 게임 개발</a></p>
# 6
# <p class="book_tit"><a href="/store/books/look.php?p_code=B9224610199">미라클 모닝 밀리어네어</a></p>
# 7
# <p class="book_tit"><a href="/store/books/look.php?p_code=B1764282969">이것이 MariaDB다</a></p>
# 8
# <p class="book_tit"><a href="/store/books/look.php?p_code=B9079387595">재미있고 빠른 첫 편지 쓰기</a></p>
# 9
# ...

# %%
import re
#도서 제목 추출 위해 정규표현식 이용. 파이썬 정규표현식 패키지는?? => re
htm=r'<p class="book_tit"><a.*?</p>'

#i=0
for part_html in re.findall(htm,html,re.DOTALL):
    #i+=1
    #print(i)
    #print(part_html)
    title=re.sub(r'<.*?>','',part_html)
    print(title)
# Out:
# 리얼월드 HTTP : 역사와 코드로 배우는 인터넷과 웹 기술
# 데이터를 부탁해 : 세상을 움직이는 데이터의 힘
# 지금 당장 마케팅 공부하라&#40;최신개정판&#41;
# 제프리 리처의 Windows via C/C++&#40;복간판&#41;
# 초보자를 위한 유니티 입문&#40;개정판&#41; : 따라 하면서 배우는 2D & 3D 게임 개발
# 미라클 모닝 밀리어네어
# 이것이 MariaDB다
# 재미있고 빠른 첫 편지 쓰기
# 회사에서 바로 통하는 실무 엑셀
# 일터의 품격
# 파이썬 라이브러리를 활용한 머신러닝&#40;번역개정판&#41; : 사이킷런 핵심 개발자가 쓴 머신러닝과 데이터 과학 실무서
# 파이썬으로 웹 크롤러 만들기&#40;2판&#41; : 초간단 나만의 웹 크롤러로 원하는 데이터를 가져오는 방법
# 2019 전기공사기사 실기
# 2019 전기공사산업기사 실기
# 맛있는 디자인 포토샵 CC 2019
# 알고리즘이 욕망하는 것들
# 한 권으로 좌뇌 개발 • 우뇌 개발 똑똑한 두뇌 연습 만 3세
# 한 권으로 좌뇌 개발 • 우뇌 개발 똑똑한 두뇌 연습 만 4세
# 한 권으로 좌뇌 개발 • 우뇌 개발 똑똑한 두뇌 연습 만 5세
# 카카오톡, 라인, 아이 메시지&페이스북 메신저와 함께하는  이모티콘으로 돈벌기
# 비됴클래스 하줜의 유튜브 동영상 편집 with 프리미어 프로
# 회사에서 바로 통하는 실무 엑셀+파워포인트+워드&한글
# 지적 대화를 위한 넓고 얕은 지식: 역사, 경제, 정치, 사회, 윤리 편
# 나는 아마존에서 미래를 다녔다
# 밑바닥부터 시작하는 딥러닝
# 개발팀장은 처음이라 시즌2
# 딥러닝 퀵스타트 : 케라스편
# 딥러닝 퀵스타트 : 파이토치편
# 처음부터 배우는 데이터 과학 with R [1회~4회 전체 과정 등록 할인 20%]
# 김왼손의 유기농냠냠파이썬 - [마감]
#   MAKE 에코백
#   MAKE 스마트폰 거치대 & 보틀
#   한빛 에코백
#   필기 독서대
#   우주에서 온 리얼타임 티셔츠

# %%
import re
#도서 제목 추출 위해 정규표현식 이용. 파이썬 정규표현식 패키지는?? => re
htm=r'<p class="book_tit"><a.*?</p>'

#i=0
for part_html in re.findall(htm,html,re.DOTALL):
    #i+=1
    #print(i)
    #print(part_html)
    title=re.sub(r'<.*?>','',part_html)
    print(title)
# Out:
# 리얼월드 HTTP : 역사와 코드로 배우는 인터넷과 웹 기술
# 데이터를 부탁해 : 세상을 움직이는 데이터의 힘
# 지금 당장 마케팅 공부하라&#40;최신개정판&#41;
# 제프리 리처의 Windows via C/C++&#40;복간판&#41;
# 초보자를 위한 유니티 입문&#40;개정판&#41; : 따라 하면서 배우는 2D & 3D 게임 개발
# 미라클 모닝 밀리어네어
# 이것이 MariaDB다
# 재미있고 빠른 첫 편지 쓰기
# 회사에서 바로 통하는 실무 엑셀
# 일터의 품격
# 파이썬 라이브러리를 활용한 머신러닝&#40;번역개정판&#41; : 사이킷런 핵심 개발자가 쓴 머신러닝과 데이터 과학 실무서
# 파이썬으로 웹 크롤러 만들기&#40;2판&#41; : 초간단 나만의 웹 크롤러로 원하는 데이터를 가져오는 방법
# 2019 전기공사기사 실기
# 2019 전기공사산업기사 실기
# 맛있는 디자인 포토샵 CC 2019
# 알고리즘이 욕망하는 것들
# 한 권으로 좌뇌 개발 • 우뇌 개발 똑똑한 두뇌 연습 만 3세
# 한 권으로 좌뇌 개발 • 우뇌 개발 똑똑한 두뇌 연습 만 4세
# 한 권으로 좌뇌 개발 • 우뇌 개발 똑똑한 두뇌 연습 만 5세
# 카카오톡, 라인, 아이 메시지&페이스북 메신저와 함께하는  이모티콘으로 돈벌기
# 비됴클래스 하줜의 유튜브 동영상 편집 with 프리미어 프로
# 회사에서 바로 통하는 실무 엑셀+파워포인트+워드&한글
# 지적 대화를 위한 넓고 얕은 지식: 역사, 경제, 정치, 사회, 윤리 편
# 나는 아마존에서 미래를 다녔다
# 밑바닥부터 시작하는 딥러닝
# 개발팀장은 처음이라 시즌2
# 딥러닝 퀵스타트 : 케라스편
# 딥러닝 퀵스타트 : 파이토치편
# 처음부터 배우는 데이터 과학 with R [1회~4회 전체 과정 등록 할인 20%]
# 김왼손의 유기농냠냠파이썬 - [마감]
#   MAKE 에코백
#   MAKE 스마트폰 거치대 & 보틀
#   한빛 에코백
#   필기 독서대
#   우주에서 온 리얼타임 티셔츠
