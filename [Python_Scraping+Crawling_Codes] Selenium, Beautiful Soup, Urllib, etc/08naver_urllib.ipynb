# %%
#포탈사이트 메인뉴스 스크래핑
#https://news.naver.com/ <- 각 분야별 뉴스 헤드라인 추출
#06naver_news.html

from urllib.request import urlopen #내장이라 별도 패키지 설치 불요!

url='https://news.naver.com/'
docs=urlopen(url)

encode=docs.info().get_content_charset()
text=docs.read().decode(encode)

with open('data/06naver_news.html','w',encoding=encode) as out: 
    out.write(text)
with open('data/06naver_news.html','r',encoding=encode) as f:
    html=f.read()

import sys
import re


#css에서... 기사제목들은 ul (=unordered list) 또는 ol (=ordered list) 내부에 있음 ㅋㅋㅋ
#언론사는 span태그에 묶여 있고.. 포티는 i class에 ㅋㅋㅋ?
#temp=re.sub(r'\s{2,}','\n',temp) #줄바꿈 왕창 있는거 한줄바꿈으로 바꾸기...


css1=r'<div class="hdline_article_tit"><a.*?</a>' 
#re.findall(css1,html,re.DOTALL)
#css2=r'<ul>.*?</ul>'
css2=r'<h5 class="blind">정치</h5>.*?</ul>'
#re.findall(css2,html,re.DOTALL)
css3=r'<h5 class="blind">경제</h5>.*?</ul>'
#re.findall(css3,html,re.DOTALL)
css4=r'<h5 class="blind">사회</h5>.*?</ul>'
css5=r'<h5 class="blind">생활\/문화</h5>.*?</ul>'
css6=r'<h5 class="blind">정치</h5>.*?</ul>'
css7=r'<h5 class="blind">세계</h5>.*?</ul>'
css8=r'<h5 class="blind">IT/과학</h5>.*?</ul>'

lst1=[]
lst2=[]
lst3=[]
lst4=[]
lst5=[]
lst6=[]
lst7=[]

for part_html in re.findall(css1,html,re.DOTALL):
    temp=re.sub(r'<.*?>','',part_html)
    temp=re.sub(r'&#40;','(',temp) #괄호 표현 바꿔주기
    temp=re.sub(r'&#41;',')',temp)
    temp=re.sub(r',','',temp)
    temp=re.sub(r'\s{2,}','\n',temp) #줄바꿈 왕창 있는거 한줄바꿈으로 바꾸기...
    temp=temp.strip()
    #print(title)
    lst1.append(temp)
for part_html in re.findall(css2,html,re.DOTALL):
    temp=re.sub(r'<i.*?</i>','',part_html)
    temp=re.sub(r'<span.*?</span>','',part_html)
    temp=re.sub(r'<.*?>','',part_html)
    temp=re.sub(r'&#40;','(',temp) #괄호 표현 바꿔주기
    temp=re.sub(r'&#41;',')',temp)
    temp=re.sub(r',','',temp)
    temp=re.sub(r'&hellip;','…',temp)
    temp=re.sub(r'&quot','"',temp)
    temp=re.sub(r'&rdquo','\'',temp)
    temp=re.sub(r'&ldquo','\'',temp)
    temp=re.sub(r'&middot','\'',temp)
    temp=re.sub(r'\s{2,}','\n',temp) #줄바꿈 왕창 있는거 한줄바꿈으로 바꾸기...
    temp=temp.strip()
    #print(title)
    lst2.append(temp)
for part_html in re.findall(css3,html,re.DOTALL):
    temp=re.sub(r'<.*?>','',part_html)
    temp=re.sub(r'&#40;','(',temp) #괄호 표현 바꿔주기
    temp=re.sub(r'&#41;',')',temp)
    temp=re.sub(r',','',temp)
    temp=re.sub(r'&hellip;','…',temp)
    temp=re.sub(r'&quot','"',temp)
    temp=re.sub(r'&rdquo','\'',temp)
    temp=re.sub(r'&ldquo','\'',temp)
    temp=re.sub(r'&middot','\'',temp)
    temp=re.sub(r'\s{2,}','\n',temp) #줄바꿈 왕창 있는거 한줄바꿈으로 바꾸기...
    temp=temp.strip()
    #print(title)
    lst3.append(temp)
for part_html in re.findall(css4,html,re.DOTALL):
    temp=re.sub(r'<.*?>','',part_html)
    temp=re.sub(r'&#40;','(',temp) #괄호 표현 바꿔주기
    temp=re.sub(r'&#41;',')',temp)
    temp=re.sub(r',','',temp)
    temp=re.sub(r'&hellip;','…',temp)
    temp=re.sub(r'&quot','"',temp)
    temp=re.sub(r'&rdquo','\'',temp)
    temp=re.sub(r'&ldquo','\'',temp)
    temp=re.sub(r'&middot','\'',temp)
    temp=re.sub(r'\s{2,}','\n',temp) #줄바꿈 왕창 있는거 한줄바꿈으로 바꾸기...
    temp=temp.strip()
    #print(title)
    lst4.append(temp)
for part_html in re.findall(css5,html,re.DOTALL):
    temp=re.sub(r'<.*?>','',part_html)
    temp=re.sub(r'&#40;','(',temp) #괄호 표현 바꿔주기
    temp=re.sub(r'&#41;',')',temp)
    temp=re.sub(r',','',temp)
    temp=re.sub(r'&hellip;','…',temp)
    temp=re.sub(r'&quot','"',temp)
    temp=re.sub(r'&rdquo','\'',temp)
    temp=re.sub(r'&ldquo','\'',temp)
    temp=re.sub(r'&middot','\'',temp)
    temp=re.sub(r'\s{2,}','\n',temp) #줄바꿈 왕창 있는거 한줄바꿈으로 바꾸기...
    temp=temp.strip()
    #print(title)
    lst5.append(temp)
for part_html in re.findall(css6,html,re.DOTALL):
    temp=re.sub(r'<.*?>','',part_html)
    temp=re.sub(r'&#40;','(',temp) #괄호 표현 바꿔주기
    temp=re.sub(r'&#41;',')',temp)
    temp=re.sub(r',','',temp)
    temp=re.sub(r'&hellip;','…',temp)
    temp=re.sub(r'&quot','"',temp)
    temp=re.sub(r'&rdquo','\'',temp)
    temp=re.sub(r'&ldquo','\'',temp)
    temp=re.sub(r'&middot','\'',temp)
    temp=re.sub(r'\s{2,}','\n',temp) #줄바꿈 왕창 있는거 한줄바꿈으로 바꾸기...
    temp=temp.strip()
    #print(title)
    lst6.append(temp)
for part_html in re.findall(css7,html,re.DOTALL):
    temp=re.sub(r'<.*?>','',part_html)
    temp=re.sub(r'&#40;','(',temp) #괄호 표현 바꿔주기
    temp=re.sub(r'&#41;',')',temp)
    temp=re.sub(r',','',temp)
    temp=re.sub(r'&hellip;','…',temp)
    temp=re.sub(r'&quot','"',temp)
    temp=re.sub(r'&rdquo','\'',temp)
    temp=re.sub(r'&ldquo','\'',temp)
    temp=re.sub(r'&middot','\'',temp)
    temp=re.sub(r'\s{2,}','\n',temp) #줄바꿈 왕창 있는거 한줄바꿈으로 바꾸기...
    temp=temp.strip()
    #print(title)
    lst7.append(temp)
    
#for i in range(len(lst2)):
#    print(lst2[i],lst3[i],lst4[i],lst5[i],lst6[i],lst7[i])

with open('data/06naver_news.csv','w',encoding='utf-8') as out:
    fmt='%s\n' #줄바꾸기 유의!
    for i in range(len(lst1)):
        out.write(fmt %(lst1[i]))
with open('data/06naver_news.csv','a',encoding='utf-8') as out:
    fmt='%s\n,%s\n,%s\n,%s\n,%s\n,%s\n' #줄바꾸기 유의!
    for i in range(len(lst2)):
        out.write(fmt %(lst2[i],lst3[i],lst4[i],lst5[i],lst6[i],lst7[i]))
