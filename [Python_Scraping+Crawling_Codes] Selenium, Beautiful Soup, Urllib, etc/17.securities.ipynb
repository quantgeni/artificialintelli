# %%
#네이버증권: 환전고시환율, 국제시장환율
#다음증권: 오늘의증시, 환율조회
from bs4 import BeautifulSoup
import requests
url1='https://finance.naver.com/' #네이버금융종합
url2='https://finance.daum.net/' #다음오늘의증시
url3='https://finance.daum.net/exchanges' #다음환율

headers={'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/73.0.3683.103 Safari/537.36'}
#브라우저가 아니지만 브라우저인 것처럼 하기 위해 인위적으로 가짜 브라우저 정보 만든 것 (스크레이핑/크롤링 사실 숨기기 위해)

res=requests.get(url1,headers=headers)
#html=BeautifulSoup(res.text,'html.parser')
html=BeautifulSoup(res.text,'lxml') #위 html.parser보다 더 빠르다는 말이..
#requests 패키지를 통해 응답받은 html 소스를 BeautifulSoup 패키지의 html.parser를 이용해서 
#DOM (Document Object Model. .. 자바스크립트 문서 동적 처리?? 계층구조로) html 계층구조로 변환

#content > div.article2 > div.section1 > div.group1 > table > tbody > tr> th > a

#content > div.article2 > div.section1 > div.group1 > table > tbody > tr > th > a

#content > div.article2 > div.section1 > div.group1 > table > tbody > tr:nth-child(2) > td:nth-child(2)

#content > div.article2 > div.section1 > div.group1 > table > tbody > tr.up.bold > td:nth-child(2)
#content > div.article2 > div.section1 > div.group1 > table > tbody > tr:nth-child(2) > td:nth-child(2)
#content > div.article2 > div.section1 > div.group1 > table > tbody > tr:nth-child(3) > td:nth-child(2)
#content > div.article2 > div.section1 > div.group1 > table > tbody > tr.up.bold > td:nth-child(3)

for part_html in html.select('div.section1 > div.group1 > table > tbody > tr> th > a'):
    #print(part_html.text.strip())
    #print(part_html.string.strip())
    print(part_html.text.strip())
for part_html in html.select('div.section1 > div.group1 > table > tbody > tr > td:nth-child(2)'):
    #print(part_html.text.strip())
    #print(part_html.string.strip())
    print(part_html.text.strip())
for part_html in html.select('div.section1 > div.group1 > table > tbody > tr > td:nth-child(3)'):
    #print(part_html.text.strip())
    #print(part_html.string.strip())
    print(part_html.text.strip())

for part_html in html.select('div.section1 > div.group2 > table > tbody > tr > th > a'):
    #print(part_html.text.strip())
    #print(part_html.string.strip())
    print(part_html.text.strip())
for part_html in html.select('div.section1 > div.group2 > table > tbody > tr > td:nth-child(2)'):
    #print(part_html.text.strip())
    #print(part_html.string.strip())
    print(part_html.text.strip())
for part_html in html.select('div.section1 > div.group2 > table > tbody > tr > td:nth-child(3)'):
    #print(part_html.text.strip())
    #print(part_html.string.strip())
    print(part_html.text.strip())

#content > div.article2 > div.section1 > div.group2 > table > tbody > tr:nth-child > th > a
#content > div.article2 > div.section1 > div.group2 > table > tbody > tr:nth-child > td:nth-child(2)
#content > div.article2 > div.section1 > div.group2 > table > tbody > tr.down.bold > td:nth-child(3)
# Out:
# 미국USD
# 일본JPY (100엔)
# 유럽연합EUR
# 중국CNY
# 1,136.40
# 1,015.23
# 1,284.64
# 169.31
# 상승 2.90
# 상승 2.72
# 상승 2.54
# 상승 0.36
# 일본 엔/달러(04.15)
# 달러/유로(04.15)
# 달러/파운드(04.15)
# 달러인덱스(04.15)
# 111.9900
# 1.1310
# 1.3116
# 96.5500
# 하락 0.03
# 하락 0.00
# 상승 0.00
# 하락 0.04

# %%
#네이버증권: 환전고시환율, 국제시장환율
#다음증권: 오늘의증시, 환율조회
from bs4 import BeautifulSoup
import requests
url1='https://finance.naver.com/' #네이버금융종합
url2='https://finance.daum.net/' #다음오늘의증시
url3='https://finance.daum.net/exchanges' #다음환율

headers={'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/73.0.3683.103 Safari/537.36'}
#브라우저가 아니지만 브라우저인 것처럼 하기 위해 인위적으로 가짜 브라우저 정보 만든 것 (스크레이핑/크롤링 사실 숨기기 위해)

res=requests.get(url1,headers=headers)
#html=BeautifulSoup(res.text,'html.parser')
html=BeautifulSoup(res.text,'lxml') #위 html.parser보다 더 빠르다는 말이..
#requests 패키지를 통해 응답받은 html 소스를 BeautifulSoup 패키지의 html.parser를 이용해서 
#DOM (Document Object Model. .. 자바스크립트 문서 동적 처리?? 계층구조로) html 계층구조로 변환

#content > div.article2 > div.section1 > div.group1 > table > tbody > tr> th > a

#content > div.article2 > div.section1 > div.group1 > table > tbody > tr > th > a

#content > div.article2 > div.section1 > div.group1 > table > tbody > tr:nth-child(2) > td:nth-child(2)

#content > div.article2 > div.section1 > div.group1 > table > tbody > tr.up.bold > td:nth-child(2)
#content > div.article2 > div.section1 > div.group1 > table > tbody > tr:nth-child(2) > td:nth-child(2)
#content > div.article2 > div.section1 > div.group1 > table > tbody > tr:nth-child(3) > td:nth-child(2)
#content > div.article2 > div.section1 > div.group1 > table > tbody > tr.up.bold > td:nth-child(3)

exchange1=[]
for part_html in html.select('div.section1 > div.group1 > table > tbody > tr'):
    #print(part_html.text.strip())
    #print(part_html.string.strip())
    exchange1.append(part_html.text.strip())
print(exchange1)

i=0
for i in range(len(exchange1)):
    print(exchange1[i].replace('\n',','))
    i+=1
    print(i)
i=0
exchange2=[]
for part_html in html.select('div.section1 > div.group2 > table > tbody > tr'):
    #print(part_html.text.strip())
    #print(part_html.string.strip())
    #print(part_html.text.strip())
    exchange2.append(part_html.text.strip())
print(exchange2)

for i in range(len(exchange2)):
    print(exchange2[i].replace('\n',','))
    i+=1
    print(i)

#content > div.article2 > div.section1 > div.group2 > table > tbody > tr:nth-child > th > a
#content > div.article2 > div.section1 > div.group2 > table > tbody > tr:nth-child > td:nth-child(2)
#content > div.article2 > div.section1 > div.group2 > table > tbody > tr.down.bold > td:nth-child(3)
# Out:
# ['미국USD\n1,135.90\n상승 2.40', '일본JPY (100엔)\n1,014.79\n상승 2.28', '유럽연합EUR\n1,284.25\n상승 2.15', '중국CNY\n169.26\n상승 0.31']
# 미국USD,1,135.90,상승 2.40
# 1
# 일본JPY (100엔),1,014.79,상승 2.28
# 2
# 유럽연합EUR,1,284.25,상승 2.15
# 3
# 중국CNY,169.26,상승 0.31
# 4
# ['일본 엔/달러(04.15)\n111.9900\n하락 0.03', '달러/유로(04.15)\n1.1310\n하락 0.00', '달러/파운드(04.15)\n1.3116\n상승 0.00', '달러인덱스(04.15)\n96.5500\n하락 0.04']
# 일본 엔/달러(04.15),111.9900,하락 0.03
# 1
# 달러/유로(04.15),1.1310,하락 0.00
# 2
# 달러/파운드(04.15),1.3116,상승 0.00
# 3
# 달러인덱스(04.15),96.5500,하락 0.04
# 4

# %%
#네이버증권: 환전고시환율, 국제시장환율
#다음증권: 오늘의증시, 환율조회
from bs4 import BeautifulSoup
import requests
url1='https://finance.naver.com/' #네이버금융종합
url2='https://finance.daum.net/' #다음오늘의증시
url3='https://finance.daum.net/exchanges' #다음환율

headers={'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/73.0.3683.103 Safari/537.36'}
#브라우저가 아니지만 브라우저인 것처럼 하기 위해 인위적으로 가짜 브라우저 정보 만든 것 (스크레이핑/크롤링 사실 숨기기 위해)

res=requests.get(url2,headers=headers)
#html=BeautifulSoup(res.text,'html.parser')
html=BeautifulSoup(res.text,'lxml') #위 html.parser보다 더 빠르다는 말이..
#requests 패키지를 통해 응답받은 html 소스를 BeautifulSoup 패키지의 html.parser를 이용해서 
#DOM (Document Object Model. .. 자바스크립트 문서 동적 처리?? 계층구조로) html 계층구조로 변환

#content > div.article2 > div.section1 > div.group1 > table > tbody > tr> th > a

#content > div.article2 > div.section1 > div.group1 > table > tbody > tr > th > a

#content > div.article2 > div.section1 > div.group1 > table > tbody > tr:nth-child(2) > td:nth-child(2)

#content > div.article2 > div.section1 > div.group1 > table > tbody > tr.up.bold > td:nth-child(2)
#content > div.article2 > div.section1 > div.group1 > table > tbody > tr:nth-child(2) > td:nth-child(2)
#content > div.article2 > div.section1 > div.group1 > table > tbody > tr:nth-child(3) > td:nth-child(2)
#content > div.article2 > div.section1 > div.group1 > table > tbody > tr.up.bold > td:nth-child(3)

#boxIndexes > div > h5 > a
#boxIndexes > div > h5 > a > em
#boxIndexes > div > span.num.up > strong
#boxIndexes > div > span.num.up > p:nth-child(2)
#boxIndexes > div > span.num.up > p:nth-child(3)


#boxIndexes > div > h5 > a
#boxIndexes > div > h5 > a > em
#boxIndexes > div> span.num.down > strong
#boxIndexes > div > span.num.up > p:nth-child(2)
#boxIndexes > div > span.num.up > p:nth-child(3)

#boxIndexes > div:nth-child(2) > span.num.down > strong

for part_html in html.select('div > h5 > a'):
    #print(part_html.text.strip())
    #print(part_html.string.strip())
    print(part_html.text.strip())
for part_html in html.select('div > h5 > a > em'):
    #print(part_html.text.strip())
    #print(part_html.string.strip())
    print(part_html.text.strip())
for part_html in html.select('boxIndexes > div > span.num.down > strong'):
    #print(part_html.text.strip())
    #print(part_html.string.strip())
    print(part_html.text.strip())
for part_html in html.select('div > span.num.up > p:nth-child(2)'):
    #print(part_html.text.strip())
    #print(part_html.string.strip())
    print(part_html.text.strip())
for part_html in html.select('div > span.num.up > p:nth-child(3)'):
    #print(part_html.text.strip())
    #print(part_html.string.strip())
    print(part_html.text.strip())

# %%
#네이버증권: 환전고시환율, 국제시장환율
#다음증권: 오늘의증시, 환율조회
from bs4 import BeautifulSoup
import requests
url1='https://finance.naver.com/' #네이버금융종합
url2='https://finance.daum.net/' #다음오늘의증시
url3='https://finance.daum.net/exchanges' #다음환율

headers={'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/73.0.3683.103 Safari/537.36'}
#브라우저가 아니지만 브라우저인 것처럼 하기 위해 인위적으로 가짜 브라우저 정보 만든 것 (스크레이핑/크롤링 사실 숨기기 위해)

res=requests.get(url3,headers=headers)
#html=BeautifulSoup(res.text,'html.parser')
html=BeautifulSoup(res.text,'lxml') #위 html.parser보다 더 빠르다는 말이..
#requests 패키지를 통해 응답받은 html 소스를 BeautifulSoup 패키지의 html.parser를 이용해서 
#DOM (Document Object Model. .. 자바스크립트 문서 동적 처리?? 계층구조로) html 계층구조로 변환


for part_html in html.select('boxContents > div.tableB > div.box_contents > div > table > tbody > tr.first > td:nth-child(1) > a'):
    #print(part_html.text.strip())
    #print(part_html.string.strip())
    print(part_html.text.strip())
for part_html in html.select('boxContents > div.tableB > div.box_contents > div > table > tbody > tr.first > td.first'):
    #print(part_html.text.strip())
    #print(part_html.string.strip())
    print(part_html.text.strip())
for part_html in html.select('boxContents > div.tableB > div.box_contents > div > table > tbody > tr.first > td:nth-child(3) > span'):
    #print(part_html.text.strip())
    #print(part_html.string.strip())
    print(part_html.text.strip())
    
#boxContents > div.tableB > div.box_contents > div > table > tbody > tr.first > td:nth-child(1) > a
#boxContents > div.tableB > div.box_contents > div > table > tbody > tr.first > td.first
#boxContents > div.tableB > div.box_contents > div > table > tbody > tr.first > td:nth-child(3) > span
