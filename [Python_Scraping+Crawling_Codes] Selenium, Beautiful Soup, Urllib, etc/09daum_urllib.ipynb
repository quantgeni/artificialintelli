# %%
#https://media.daum.net/
#언론사별 뉴스헤드라인 + 댓글많은뉴스 + 연령별인기뉴스

from urllib.request import urlopen #내장이라 별도 패키지 설치 불요!

url='https://media.daum.net/'
docs=urlopen(url)

encode=docs.info().get_content_charset()
text=docs.read().decode(encode)

with open('data/07daum_news.html','w',encoding=encode) as out: 
    out.write(text)
with open('data/07daum_news.html','r',encoding=encode) as f:
    html=f.read()

import sys
import re

#css1=r'주요 이슈 기사 목록.*?</strong>'
css1=r'<ul class="list_view">.*?</ul>'
css2=r'<ul class="list_headline">.*?</ul>'
css3=r'<ol class="list_popcmt">.*?</ol>'
css4=r'<ul class="list_agenews list_female>.*?</ul>'
css5=r'<ul class="list_agenews list_male">.*?</ul>'
#re.findall(css1,html,re.DOTALL)
#css2=r'<h3 class="tit_news">댓글 많은 뉴스.*?<a href="/ranking/bestreply/" class="link_more">'
#re.findall(css2,html,re.DOTALL)
css3=r'<h3 class="tit_news">연령별 인기뉴스.*?<a href="/ranking/age/" class="link_more">'
#re.findall(css3,html,re.DOTALL)
#css4=r'<h5 class="blind">사회</h5>.*?</ul>'
#css5=r'<h5 class="blind">생활\/문화</h5>.*?</ul>'
#css6=r'<h5 class="blind">정치</h5>.*?</ul>'
#css7=r'<h5 class="blind">세계</h5>.*?</ul>'
#css8=r'<h5 class="blind">IT/과학</h5>.*?</ul>'

lst1=[]
lst2=[]
lst3=[]
#lst4=[]
#lst5=[]
#lst6=[]
#lst7=[]
i=0
for part_html in re.findall(css1,html,re.DOTALL):
    temp=re.sub(r'<.*?>','',part_html)
    temp=re.sub(r'&#40;','(',temp) #괄호 표현 바꿔주기
    temp=re.sub(r'&#41;',')',temp)
    temp=re.sub(r',','',temp)
    temp=re.sub(r'<i.*?</i>','',part_html)
    temp=re.sub(r'<span.*?</span>','',part_html)
    temp=re.sub(r'<.*?>','',part_html)
    temp=re.sub(r'&#40;','(',temp) #괄호 표현 바꿔주기
    temp=re.sub(r'&#41;',')',temp)
    temp=re.sub(r',','',temp)
    temp=re.sub(r'&hellip;','…',temp)
    temp=re.sub(r'&quot','"',temp)
    temp=re.sub(r'&rdquo','\'',temp)
    temp=re.sub(r'&ldquo','\'',temp)
    temp=re.sub(r'&middot','\'',temp)
    temp=re.sub(r'\s{2,}','\n',temp) #줄바꿈 왕창 있는거 한줄바꿈으로 바꾸기...
    temp=temp.strip()
    #print(title)
    lst1.append(temp)
    i+=1
    print(i)
    print(lst1)
for part_html in re.findall(css2,html,re.DOTALL):
    temp=re.sub(r'<.*?>','',part_html)
    temp=re.sub(r'&#40;','(',temp) #괄호 표현 바꿔주기
    temp=re.sub(r'&#41;',')',temp)
    temp=re.sub(r'<i.*?</i>','',part_html)
    temp=re.sub(r'<span.*?</span>','',part_html)
    temp=re.sub(r'<.*?>','',part_html)
    temp=re.sub(r'&#40;','(',temp) #괄호 표현 바꿔주기
    temp=re.sub(r'&#41;',')',temp)
    temp=re.sub(r',','',temp)
    temp=re.sub(r'&hellip;','…',temp)
    temp=re.sub(r'&quot','"',temp)
    temp=re.sub(r'&rdquo','\'',temp)
    temp=re.sub(r'&ldquo','\'',temp)
    temp=re.sub(r'&middot','\'',temp)
    temp=re.sub(r'\s{2,}','\n',temp) #줄바꿈 왕창 있는거 한줄바꿈으로 바꾸기...
    temp=re.sub(r',','',temp)
    temp=temp.strip()
    #print(title)
    lst2.append(temp)
    print(temp)
for part_html in re.findall(css3,html,re.DOTALL):
    temp=re.sub(r'<.*?>','',part_html)
    temp=re.sub(r'&#40;','(',temp) #괄호 표현 바꿔주기
    temp=re.sub(r'&#41;',')',temp)
    temp=re.sub(r'<i.*?</i>','',part_html)
    temp=re.sub(r'<span.*?</span>','',part_html)
    temp=re.sub(r'<.*?>','',part_html)
    temp=re.sub(r'&#40;','(',temp) #괄호 표현 바꿔주기
    temp=re.sub(r'&#41;',')',temp)
    temp=re.sub(r',','',temp)
    temp=re.sub(r'&hellip;','…',temp)
    temp=re.sub(r'&quot','"',temp)
    temp=re.sub(r'&rdquo','\'',temp)
    temp=re.sub(r'&ldquo','\'',temp)
    temp=re.sub(r'&middot','\'',temp)
    temp=re.sub(r'\s{2,}','\n',temp) #줄바꿈 왕창 있는거 한줄바꿈으로 바꾸기...
    temp=re.sub(r',','',temp)
    temp=re.sub(r'<!--|-->|0|댓글','',temp) # | 는 or 조건임!! 한꺼번에 쓰기!!
    temp=temp.strip()
    lst3.append(temp)
    
#for i in range(len(lst2)):
#    print(lst2[i],lst3[i],lst4[i],lst5[i],lst6[i],lst7[i])

with open('data/07daum_news.csv','w',encoding='utf-8') as out:
    fmt='%s\n' #줄바꾸기 유의!
    for i in range(len(lst1)):
        out.write(fmt %(lst1[i]))
with open('data/07daum_news.csv','a',encoding='utf-8') as out:
    fmt='%s\n' #줄바꾸기 유의!
    for i in range(len(lst2)):
        out.write(fmt %(lst2[i]))
with open('data/07daum_news.csv','a',encoding='utf-8') as out:
    fmt='%s\n' #줄바꾸기 유의!
    for i in range(len(lst3)):
        out.write(fmt %(lst3[i]))
# Out:
# 1
# ['네타냐후 시리아 공습 인정? "힘은 평화의 기본적 조건"머니투데이\n유럽 전직 지도자들 트럼프 친 이스라엘 중동 정책 비...연합뉴스\n이란 외무 "美 이스라엘 챙기다 중동 갈등 일으켜"연합뉴스\n브라질 보우소나루 "유엔서 어정쩡한 표결 행위 없을 것...연합뉴스\n폼페이오 "네타냐후 총선 승리 축하..양국동맹 깨질수 ...연합뉴스']
# 2
# 연합뉴스
# 해경 서부 정비창 사업 목포 허사도에 신설로 가닥
# 연합뉴스
# 서울 아파트 53개동 '붕괴 위험'..안전불감증 심각
# 네팔 벼락사고 사망자 8년간 800여명.."홍수 피해보다 커"
# 연합뉴스
# 하남 '캠프 콜번' 부지 대학유치→도시개발 변경
# 연합뉴스
# 애플vs퀄컴 3조원 규모 소송 시작..공룡기업 간 싸움
# 뉴시스
# 계단 오르기 잘하면 장수하는 이유
# 코메디닷컴

# %%
from urllib.request import urlopen #내장이라 별도 패키지 설치 불요!

url='https://media.daum.net/'
docs=urlopen(url)

encode=docs.info().get_content_charset()
text=docs.read().decode(encode)

with open('data/07daum_news.html','w',encoding=encode) as out: 
    out.write(text)
with open('data/07daum_news.html','r',encoding=encode) as f:
    html=f.read()

import sys
import re

#css1=r'주요 이슈 기사 목록.*?</strong>'
css1=r'<ul class="list_view">.*?</ul>'


lst1=[]

i=0
for part_html in re.findall(css1,html,re.DOTALL):
    temp=re.sub(r'<.*?>','',part_html)
    temp=re.sub(r'&#40;','(',temp) #괄호 표현 바꿔주기
    temp=re.sub(r'&#41;',')',temp)
    temp=re.sub(r',','',temp)
    temp=re.sub(r'<i.*?</i>','',part_html)
    temp=re.sub(r'<span.*?</span>','',part_html)
    temp=re.sub(r'<.*?>','',part_html)
    temp=re.sub(r'&#40;','(',temp) #괄호 표현 바꿔주기
    temp=re.sub(r'&#41;',')',temp)
    temp=re.sub(r',','',temp)
    temp=re.sub(r'&hellip;','…',temp)
    temp=re.sub(r'&quot','"',temp)
    temp=re.sub(r'&rdquo','\'',temp)
    temp=re.sub(r'&ldquo','\'',temp)
    temp=re.sub(r'&middot','\'',temp)
    temp=re.sub(r'\s{2,}','\n',temp) #줄바꿈 왕창 있는거 한줄바꿈으로 바꾸기...
    temp=temp.strip()
    #print(title)
    #lst1.append(temp)
    i+=1
    print(i)
    print(temp)
    #print(lst1)
# Out:
# 1
# 네타냐후 시리아 공습 인정? "힘은 평화의 기본적 조건"머니투데이
# 유럽 전직 지도자들 트럼프 친 이스라엘 중동 정책 비...연합뉴스
# 이란 외무 "美 이스라엘 챙기다 중동 갈등 일으켜"연합뉴스
# 브라질 보우소나루 "유엔서 어정쩡한 표결 행위 없을 것...연합뉴스
# 폼페이오 "네타냐후 총선 승리 축하..양국동맹 깨질수 ...연합뉴스
# 2
# 故 조양호 회장 빈소 나흘째..정의선·현정은 등 조문 이어져연합뉴스
# "좋은 분이셨다" 정의선·허창수 故조양호 회장 조문머니투데이
# 故조양호 장례 나흘째..정의선·손학규·현정은 등 정재계...뉴시스
# 故 조양호 회장 빈소 사흘째..김연아·美대사 등 추모 ...뉴스1
# 故 조양호 회장 빈소에 이틀째 조문행렬..삼남매 침통한...연합뉴스
# 3
# '동상이몽' 미·일 무역협상 시작..입장차 커 난항 예상연합뉴스
# 美 '중국제조2025' 묵인하나.."내달 합의 위해 ...연합뉴스
# 中화웨이 런정페이 회장 "멍완저우는 미중 무역전쟁 희생...이데일리
# 환율카드까지 꺼낸 美..'원 사이드 게임' 되나서울경제
# 15일 미일 무역협상 개시..日 원치않는 환율 협상 ...서울경제
# 4
# 금호그룹 긴급 이사회..아시아나항공 매각안 논의뉴스1
# 아시아나항공 매각 전망..금호 지배구조 살펴보니뉴시스
# 금호산업 '아시아나 매각 논의' 긴급 이사회..항공산...아시아경제
# 아시아나 매각 수순..재계 25위 금호그룹 중견기업으...뉴시스
# 아시아나항공 누가 인수할까..SK·한화·애경 거론 롯...뉴시스
# 5
# 통일부 "화상상봉장 지원장비 전달 조만간 北과 협의"뉴시스
# 통일부 "화상상봉 北지원장비 구입 마무리..곧 北과 협...뉴스1
# 통일부 "화상상봉장 지원장비 구입완료..조만간 북측과 ...연합뉴스
# 김연철 취임 후 첫 정책행보는 '이산가족'..내주 한...연합뉴스
# 이산가족 화상상봉장 13곳 개·보수 시작..12년 만에...경향신문
