# %%
#https://media.daum.net/cp/310
#웹문서 저장 시 파일명은 10jtbc_news.html
#뉴스제목+간략뉴스

from urllib.request import urlopen
import re

#url1='https://media.daum.net/cp/310'
#url='https://media.daum.net/cp/310?regDate=20190410'

for i in range(1,5+1):
    url1='https://media.daum.net/cp/310?page=%d' %i
    docs=urlopen(url1)

    encode=docs.info().get_content_charset()
    text=docs.read().decode(encode)


    with open('data/10jtbc_news.html','w',encoding=encode) as out: 
        out.write(text)
    with open('data/10jtbc_news.html','r',encoding=encode) as f:
        html=f.read()

    css1=r'<strong class="tit_thumb">.*?</a>'
    css2=r'<span class="link_txt">.*?</span>'


    lst1=[]
    lst2=[]
#lst3=[]
#lst4=[]
#lst5=[]
#lst6=[]
#lst7=[]

    for part_html in re.findall(css1,html,re.DOTALL):
        temp=re.sub(r'<.*?>','',part_html)
        temp=re.sub(r'&#40;','(',temp) #괄호 표현 바꿔주기
        temp=re.sub(r'&#41;',')',temp)
        temp=re.sub(r',','',temp)
        temp=re.sub(r'<i.*?</i>','',part_html)
        temp=re.sub(r'<span.*?</span>','',part_html)
        temp=re.sub(r'<.*?>','',part_html)
        temp=re.sub(r'&#40;','(',temp) #괄호 표현 바꿔주기
        temp=re.sub(r'&#41;',')',temp)
        temp=re.sub(r',','',temp)
        temp=re.sub(r'&hellip;','…',temp)
        temp=re.sub(r'&quot','"',temp)
        temp=re.sub(r'&rdquo','\'',temp)
        temp=re.sub(r'&ldquo','\'',temp)
        temp=re.sub(r'&middot','\'',temp)
        temp=re.sub(r'\s{2,}','\n',temp) #줄바꿈 왕창 있는거 한줄바꿈으로 바꾸기...
        temp=temp.strip()
        #print(title)
        lst1.append(temp)
    for part_html in re.findall(css2,html,re.DOTALL):
        temp=re.sub(r'<.*?>','',part_html)
        temp=re.sub(r'&#40;','(',temp) #괄호 표현 바꿔주기
        temp=re.sub(r'&#41;',')',temp)
        temp=re.sub(r'<i.*?</i>','',part_html)
        temp=re.sub(r'<span.*?</span>','',part_html)
        temp=re.sub(r'<.*?>','',part_html)
        temp=re.sub(r'&#40;','(',temp) #괄호 표현 바꿔주기
        temp=re.sub(r'&#41;',')',temp)
        temp=re.sub(r',','',temp)
        temp=re.sub(r'&hellip;','…',temp)
        temp=re.sub(r'&quot','"',temp)
        temp=re.sub(r'&rdquo','\'',temp)
        temp=re.sub(r'&ldquo','\'',temp)
        temp=re.sub(r'&middot','\'',temp)
        temp=re.sub(r'\s{2,}','\n',temp) #줄바꿈 왕창 있는거 한줄바꿈으로 바꾸기...
        temp=re.sub(r',','',temp)
        temp=re.sub(r'<!--|-->|0|댓글','',temp) # | 는 or 조건임!! 한꺼번에 쓰기!!
        temp=temp.strip()
        #print(title)
        lst2.append(temp)
    

    #for i in range(len(lst2)):
    #    print(lst2[i],lst3[i],lst4[i],lst5[i],lst6[i],lst7[i])

    with open('data/10jtbc_news2.csv','a',encoding='utf-8') as out:
        fmt='%s\n%s\n' #줄바꾸기 유의!
        for i in range(len(lst1)-2): #개수 맞춰주기 ㅋㅋㅋㅋ
            out.write(fmt %(lst1[i],lst2[i]))
    #with open('data/10jtbc_news.csv','a',encoding='utf-8') as out:
    #    fmt='%s\n' #줄바꾸기 유의!
    #    for i in range(len(lst2)):
    #        out.write(fmt %(lst2[i]))

    #        for i in range(len(ls))

# %%
#https://media.daum.net/cp/310
#웹문서 저장 시 파일명은 10jtbc_news.html
#뉴스제목+간략뉴스

from urllib.request import urlopen
import re

#url1='https://media.daum.net/cp/310'
#url='https://media.daum.net/cp/310?regDate=20190410'


url1='https://media.daum.net/cp/310'
docs=urlopen(url1)

encode=docs.info().get_content_charset()
text=docs.read().decode(encode)


with open('data/10jtbc_news.html','w',encoding=encode) as out: 
    out.write(text)
with open('data/10jtbc_news.html','r',encoding=encode) as f:
    html=f.read()

css1=r'<strong class="tit_thumb">.*?</a>'
css2=r'<span class="link_txt">.*?</span>'
#현재 뉴스 마지막 페이지의 마지막 페이지 알아내기
css3=r'<span class=" screen_out">.*?<a.*?</span>'


lst1=[]
lst2=[]
#lst3=[]
#lst4=[]
#lst5=[]
#lst6=[]
#lst7=[]

for part_html in re.findall(css1,html,re.DOTALL):
    temp=re.sub(r'<.*?>','',part_html)
    temp=re.sub(r'&#40;','(',temp) #괄호 표현 바꿔주기
    temp=re.sub(r'&#41;',')',temp)
    temp=re.sub(r',','',temp)
    temp=re.sub(r'<i.*?</i>','',part_html)
    temp=re.sub(r'<span.*?</span>','',part_html)
    temp=re.sub(r'<.*?>','',part_html)
    temp=re.sub(r'&#40;','(',temp) #괄호 표현 바꿔주기
    temp=re.sub(r'&#41;',')',temp)
    temp=re.sub(r',','',temp)
    temp=re.sub(r'&hellip;','…',temp)
    temp=re.sub(r'&quot','"',temp)
    temp=re.sub(r'&rdquo','\'',temp)
    temp=re.sub(r'&ldquo','\'',temp)
    temp=re.sub(r'&middot','\'',temp)
    temp=re.sub(r'\s{2,}','\n',temp) #줄바꿈 왕창 있는거 한줄바꿈으로 바꾸기...
    temp=temp.strip()
    #print(title)
    lst1.append(temp)
for part_html in re.findall(css2,html,re.DOTALL):
    temp=re.sub(r'<.*?>','',part_html)
    temp=re.sub(r'&#40;','(',temp) #괄호 표현 바꿔주기
    temp=re.sub(r'&#41;',')',temp)
    temp=re.sub(r'<i.*?</i>','',part_html)
    temp=re.sub(r'<span.*?</span>','',part_html)
    temp=re.sub(r'<.*?>','',part_html)
    temp=re.sub(r'&#40;','(',temp) #괄호 표현 바꿔주기
    temp=re.sub(r'&#41;',')',temp)
    temp=re.sub(r',','',temp)
    temp=re.sub(r'&hellip;','…',temp)
    temp=re.sub(r'&quot','"',temp)
    temp=re.sub(r'&rdquo','\'',temp)
    temp=re.sub(r'&ldquo','\'',temp)
    temp=re.sub(r'&middot','\'',temp)
    temp=re.sub(r'\s{2,}','\n',temp) #줄바꿈 왕창 있는거 한줄바꿈으로 바꾸기...
    temp=re.sub(r',','',temp)
    temp=re.sub(r'<!--|-->|0|댓글','',temp) # | 는 or 조건임!! 한꺼번에 쓰기!!
    temp=temp.strip()
    #print(title)
    lst2.append(temp)
for part_html in re.findall(css3,html,re.DOTALL):
    temp=re.sub(r'<.*?>','',part_html)
    temp=re.sub(r'현재 페이지','',temp) #괄호 표현 바꿔주기
    temp=re.sub(r'&#40;','(',temp) #괄호 표현 바꿔주기
    temp=re.sub(r'&#41;',')',temp)
    temp=re.sub(r'<i.*?</i>','',part_html)
    temp=re.sub(r'<span.*?</span>','',part_html)
    temp=re.sub(r'<.*?>','',part_html)
    temp=re.sub(r'&#40;','(',temp) #괄호 표현 바꿔주기
    temp=re.sub(r'&#41;',')',temp)
    temp=re.sub(r',','',temp)
    temp=re.sub(r'&hellip;','…',temp)
    temp=re.sub(r'&quot','"',temp)
    temp=re.sub(r'&rdquo','\'',temp)
    temp=re.sub(r'&ldquo','\'',temp)
    temp=re.sub(r'&middot','\'',temp)
    temp=re.sub(r'\s{2,}','\n',temp) #줄바꿈 왕창 있는거 한줄바꿈으로 바꾸기...
    temp=re.sub(r',','',temp)
    temp=re.sub(r'<!--|-->|0|댓글','',temp) # | 는 or 조건임!! 한꺼번에 쓰기!!
    #tempnum=temp.strip('/n')
    #print(tempnum.split('\n')[-1])
    print(temp)

#for i in range(len(lst2)):
#    print(lst2[i],lst3[i],lst4[i],lst5[i],lst6[i],lst7[i])

with open('data/10jtbc_news2.csv','a',encoding='utf-8') as out:
    fmt='%s\n%s\n%s\n' #줄바꾸기 유의!
    for i in range(len(lst1)-2): #개수 맞춰주기 ㅋㅋㅋㅋ
        out.write(fmt %(lst1[i],lst2[i])
#with open('data/10jtbc_news.csv','a',encoding='utf-8') as out:
#    fmt='%s\n' #줄바꾸기 유의!
#    for i in range(len(lst2)):
#        out.write(fmt %(lst2[i]))

#        for i in range(len(ls))

# %%
a=3
b=3
print(a+b)
