# %%
#포털사이트에서 검색어를 입력하고 출력된 결과 중 검색제목과 링크 추출
from bs4 import BeautifulSoup
import requests
#url1='https://search.naver.com/search.naver?sm=top_hty&fbm=0&ie=utf8&query=html5'
url1='https://search.naver.com/search.naver'
#url1='https://search.naver.com/search.naver?sm=tab_hty.top&where=nexearch&query=html&oquery=html&tqi=U7TKMdpVuENsstvIw%2FZssssstN4-456515'
#url1='https://search.naver.com/search.naver?sm=top_hty&fbm=1&ie=utf8&query=html'
#url2='https://finance.daum.net/' #다음오늘의증시
#url3='https://finance.daum.net/exchanges' #다음환율
params={'query':'html'}
headers={'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/73.0.3683.103 Safari/537.36'}
#브라우저가 아니지만 브라우저인 것처럼 하기 위해 인위적으로 가짜 브라우저 정보 만든 것 (스크레이핑/크롤링 사실 숨기기 위해)
#res=requests.get(url1,headers=headers)
res=requests.get(url1,headers=headers,params=params)
#html=BeautifulSoup(res.text,'html.parser')
html=BeautifulSoup(res.text,'lxml') #위 html.parser보다 더 빠르다는 말이..
#requests 패키지를 통해 응답받은 html 소스를 BeautifulSoup 패키지의 html.parser를 이용해서 
#DOM (Document Object Model. .. 자바스크립트 문서 동적 처리?? 계층구조로) html 계층구조로 변환

#power_link_body > ul > li.lst.lst1.ext_link.type_img > div > a
#power_link_body > ul > li.lst.lst1.ext_link.type_img > div > div > a
#power_link_body > ul > li.lst.lst1.ext_link.type_img > div > p

#main_pack > div.sp_kindic.sc._sp_kindic > div.sc_kindic > div > div:nth-child(1) > div > div.tit_box > a > strong
#main_pack > div.sp_kindic.sc._sp_kindic > div.sc_kindic > div > div:nth-child(1) > div > p

#main_pack > div.cafe.section._cafeBase._prs_caf > ul > li:nth-child(2) > dl > dt > a
#main_pack > div.cafe.section._cafeBase._prs_caf > ul > li:nth-child(1) > dl > dd.sh_cafe_passage
#main_pack > div.cafe.section._cafeBase._prs_caf > ul > li:nth-child(1) > dl > dd.txt_block > span > a.url

#main_pack > div.sp_post.section > ul > li:nth-child(1) > dl > dt > a
#main_pack > div.sp_post.section > ul > li:nth-child(1) > dl > dd:nth-child(3)

#web_layer_0 > dl > dt > a.title_link
#main_pack > div.book_list.section > ul > li:nth-child(2) > dl > dt > a
#id_ldic_nx_section_layer > ul > li > dl > dd > dl > dt > a
#biz_site_body > ul > li.lst.lst1 > div > a
#power_contents_body > ul > li:nth-child(1) > div.inner > a

#main_pack > div.sp_kindic.sc._sp_kindic > div.api_subject_bx > div.group_kindic > div:nth-child(1) > div > div.tit_box > a
#for part_html in html.select('div > div > div.tit_box > a'):
    #print(part_html.text.strip())
    #print(part_html.string.strip())
 #   print(part_html.text.strip(),part_html.get('href'))
#print()
#for part_html in html.select('p.txt_box'):
    #print(part_html.text.strip())
    #print(part_html.string.strip())
 #   print(part_html.text.strip())
#print()   
#for part_html in html.select('div.sp_post.section > ul > li > dl > dt > a'):
    #print(part_html.text.strip())
    #print(part_html.string.strip())
 #   print(part_html.text.strip(),part_html.get('href'))
#print()
#for part_html in html.select('div.sp_post.section > ul > li > dl > dd'):
    #print(part_html.text.strip())
    #print(part_html.string.strip())
 
#print(part_html.text.strip())
    
#web_layer_0 > dl > dt > a.title_link
#web_layer_0 > dl > dd.sh_web_passage > strong

#web_layer_0 > dl > dd.sh_web_passage

#for part_html in html.select('dl > dt > a.title_link'):
    #print(part_html.text.strip())
    #print(part_html.string.strip())
 #   print(part_html.text.strip(),part_html.get('href'))
#print()
for part_html in html.select('dl > dd.sh_web_passage'):
    #print(part_html.text.strip())
    #print(part_html.string.strip())
    print(part_html.text.strip())
#li.sh_web_top > dl > dd.sh_web_passage
#web_layer_1

#web_layer_0 > dl > dd.sh_web_passage
# Out:
# A resource for developers looking to put HTML5 to use today, including information on specific features and when to use them in your apps.
# 하위 문서: HTML/태그 인터넷 관련 정보 1. 개요 2. 설명 3. 태그 4. 버전 5. HTML 문서 저장 방법 6. 트랜스컴파일러 7. 바깥 고리 1. 2. 3. 4. 5. 6. 7. 8. 9. Hello, world! HTML5로 작성한 Hello, world!. 본문 내용에 출력된다. 마셜제도 에서 팀 버너스리 경을...
# HTML5 Tutorial ❮ Home Next ❯ With HTML you can create your own Website. This tutorial teaches you everything about HTML. HTML is easy to learn - You will enjoy it. Examples in Every Chapter This HTML tutorial contains...

# %%
#포털사이트에서 검색어를 입력하고 출력된 결과 중 검색제목과 링크 추출
from bs4 import BeautifulSoup
import requests
#url1='https://search.naver.com/search.naver?sm=top_hty&fbm=0&ie=utf8&query=html5'
#url1='https://search.naver.com/search.naver'

#url1='https://www.google.com/search'
url1='https://www.google.com/search'
#url1='https://search.naver.com/search.naver?sm=tab_hty.top&where=nexearch&query=html&oquery=html&tqi=U7TKMdpVuENsstvIw%2FZssssstN4-456515'
#url1='https://search.naver.com/search.naver?sm=top_hty&fbm=1&ie=utf8&query=html'
#url2='https://finance.daum.net/' #다음오늘의증시
#url3='https://finance.daum.net/exchanges' #다음환율
params={'q':'html5'}
headers={'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/73.0.3683.103 Safari/537.36'}
#브라우저가 아니지만 브라우저인 것처럼 하기 위해 인위적으로 가짜 브라우저 정보 만든 것 (스크레이핑/크롤링 사실 숨기기 위해)
#res=requests.get(url1,headers=headers)
res=requests.get(url1,headers=headers,params=params)
#html=BeautifulSoup(res.text,'html.parser')
html=BeautifulSoup(res.text,'lxml') #위 html.parser보다 더 빠르다는 말이..

#rso > div > div > div:nth-child(1) > div > div > div.r > a > h3
#rso > div > div > div:nth-child(2) > div > div > div.r > a > h3
#rso > div > div > div:nth-child(8) > div > div > div.r > a > h3
#rso > div > div > div:nth-child(8) > div > div > div.r > a > h3
#rso > div > div > div:nth-child(1) > div > div > div.s > div > span
#rso > div > div > div:nth-child(1) > div > div.rc > div.r > a > h3

i=0
for part_html in html.select('h3.LC20lb'):
    #print(part_html.text.strip())
    #print(part_html.string.strip())
    i+=1
    print(i)
    print(part_html.text.strip())
print()
i=0
for part_html in html.select('cite.iUh30'):
    #print(part_html.text.strip())
    #print(part_html.string.strip())
    i+=1
    print(i)
    print(part_html.text.strip())
print()
# Out:
# 1
# 1 HTML5 기본 문법 - PoiemaWeb
# 2
# HTML5 - 위키백과, 우리 모두의 백과사전
# 3
# HTML5 Introduction - W3Schools
# 4
# HTML5 - 나무위키
# 5
# KOREA HTML5
# 6
# <HTML5 강좌 리스트>
# 7
# HTML5 소개 - HTML | MDN
# 8
# HTML5 - MDN - Mozilla
# 9
# W3C HTML5 Logo - World Wide Web Consortium
# 10
# HTML5 Rocks - A resource for open web HTML5 developers
#
# 1
# https://poiemaweb.com/html5-syntax
# 2
# https://ko.wikipedia.org/wiki/HTML5
# 3
# https://www.w3schools.com/html/html5_intro.asp
# 4
# https://namu.wiki/w/HTML5
# 5
# https://www.koreahtml5.kr/
# 6
# direct.co.kr/cs/HTML5.pdf
# 7
# https://developer.mozilla.org/ko/docs/Web/HTML/HTML5/Introduction_to_HTML5
# 8
# https://developer.mozilla.org/ko/docs/Web/HTML/HTML5
# 9
# https://www.w3.org/html/logo/
# 10
# https://www.html5rocks.com/en/
